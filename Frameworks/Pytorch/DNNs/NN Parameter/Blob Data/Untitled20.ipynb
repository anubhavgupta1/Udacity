# %% [markdown]
# <a href="https://colab.research.google.com/github/anubhavgupta1/Udacity/blob/main/Frameworks/Pytorch/DNNs/NN%20Parameter/Blob%20Data/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib.colors
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error, log_loss
from tqdm import tqdm_notebook 
import seaborn as sns
import time
from IPython.display import HTML
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import OneHotEncoder
from sklearn.datasets import make_blobs

import torch

# %%
torch.manual_seed(0)

# %%
my_cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ["red","yellow","green"])

# %% [markdown]
# ## Generate Dataset

# %%
data, labels = make_blobs(n_samples=1000, centers=4, n_features=2, random_state=0)
print(data.shape, labels.shape)
# Out:
# (1000, 2) (1000,)

# %% [markdown]
# ## Plot the Data

# %%
plt.scatter(data[:,0], data[:,1], c=labels, cmap=my_cmap)
plt.show()

# %% [markdown]
# ## Train Test Split

# %%
X_train, X_val, Y_train, Y_val = train_test_split(data, labels, stratify=labels, random_state=0)
print(X_train.shape, X_val.shape, labels.shape)
# Out:
# (750, 2) (250, 2) (1000,)

# %% [markdown]
# ## Using torch tensors and autograd

# %%
X_train, Y_train, X_val, Y_val = map(torch.tensor, (X_train, Y_train, X_val, Y_val))

# %%
print(X_train.shape, Y_train.shape)
# Out:
# torch.Size([750, 2]) torch.Size([750])

# %%
def accuracy(y_hat, y):
  pred = torch.argmax(y_hat, dim=1)
  return (pred == y).float().mean()

# %% [markdown]
# ## Model Class

# %%
import torch.nn.functional as F
import torch.nn as nn

# %%
class BlobData(nn.Module):
  
  def __init__(self):
    super().__init__()
    torch.manual_seed(0)
    self.weights1 = nn.Parameter(torch.randn(2, 2) / math.sqrt(2))
    self.bias1 = nn.Parameter(torch.zeros(2))
    self.weights2 = nn.Parameter(torch.randn(2, 4) / math.sqrt(2))
    self.bias2 = nn.Parameter(torch.zeros(4))

  def predict(self, X):
    a1 = torch.matmul(X, self.weights1) + self.bias1 # (N, 2) x (2, 2) -> (N, 2)
    h1 = a1.sigmoid() # (N, 2)
    a2 = torch.matmul(h1, self.weights2) + self.bias2 # (N, 2) x (2, 4) -> (N, 4)
    h2 = a2.exp()/a2.exp().sum(-1).unsqueeze(-1) # (N, 4)
    return h2
  
  def accuracy(self, y_hat, y):
    pred_labels = torch.argmax(y_hat, dim=1)
    pred_binary = (pred_labels == y).float()
    average_acc = pred_binary.mean()
    return  average_acc

  def fit(self,X,Y,epochs = 1000, learning_rate = 1):
    loss_arr = []
    acc_arr  = []
    for epoch in range(epochs):
      Y_hat = self.predict(X)
      
      loss =  F.cross_entropy(Y_hat, Y)
      loss.backward()
      loss_arr.append(loss.item())
      
      acc = self.accuracy(Y_hat, Y)
      acc_arr.append(acc.item())
      
      with torch.no_grad():
        for param in self.parameters():
          param -= learning_rate * param.grad
        self.zero_grad()
    
    plt.plot(loss_arr, 'r-')
    plt.plot(acc_arr, 'b-')
    plt.show()
    
    print('Loss before training', loss_arr[0])
    print('Loss after training', loss_arr[-1])
    return loss_arr, acc_arr

# %%
model = BlobData()
loss, acc = model.fit(X_train.float(),Y_train.long())
# Out:
# Loss before training 1.4111980199813843
# Loss after training 0.9939236640930176

# %%
Y_pred = model.predict(X_val.float())
test_acc = model.accuracy(Y_pred,Y_val.long())

# %%
print("Training accuracy is : ", acc[-1])
print("Test accuracy is : ", test_acc.item())
# Out:
# Training accuracy is :  0.7773333191871643
# Test accuracy is :  0.7720000147819519

# %%
Y_pred_train = model.predict(X_train.float())
Y_pred_train = Y_pred_train.float()
Y_pred_train = Y_pred_train.detach().numpy()
Y_pred_train = np.argmax(Y_pred_train, axis=1)

# %%
X1,X2,Y = (X_train[:,0]).float(), (X_train[:,1]).float(),Y_train.numpy() 
X1, X2 = X1.numpy(), X2.numpy()

# %%
plt.scatter(X1, X2, c=Y, cmap=my_cmap)
plt.show()

# %%
plt.scatter(X1, X2, c=Y_pred_train, cmap=my_cmap, s=15*(np.abs(np.sign(Y_pred_train-Y))+.1))
plt.show()
